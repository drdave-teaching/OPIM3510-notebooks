# %% [markdown]
# # Individual Assignment 1: Subsetting Data and Statistics (Spring 2024)
#
#
# **OPIM 3510: Business Data Analytics I - University of Connecticut**
#
# ---------------------------------
#
# In this assignment, we will explore selecting data based on a condition from the toy CA housing dataset [more details here: https://developers.google.com/machine-learning/crash-course/california-housing-data-description]. You will do data subsetting of various rows and columns. For simplicity and so that you can check your work, we will only keep the first 10 rows as a subset to work with.
#
# **100 pts total, 10 pts each.** For data selection questions, print the output and print the shape to confirm your answer ( it is always good to check your work!) Otherwise, only partial credit. Be careful and remember that Python counts from 0 not from 1! For stats questions, please make sure you answer the question and write code if necessary.
#
# * 1) Select the first 5 rows and all columns.
# * 2) Select the last 6 rows and all columns.
# * 3) Select the third through fifth row and the first three columns.
# * 4) Select the fouth through eighth row and the last three columns.
# * 5) Select the second through eighth row and the eighth, ninth and tenth column.
# * 6) Select the third through eighth row and the second, third and fourth column.
# * 7) What does it mean when the mean is larger than the median value?
# * 8) Use `df.describe()` to calculate a numeric statistical summary of all the columns you see. Tell me three interesting things that you notice in the output! Use bullets and don't be afraid to add some extra detail.
# * 9) Use `df.info()` to inpsect the datatypes. Calculate the mean of 'median_house_value' column with numpy and pandas.
# * 10) Calculate the 73rd percentile of the `median_house_value` column and explain what it means in plain language!
#
# [TowardsDataScience](https://towardsdatascience.com/how-to-use-loc-and-iloc-for-selecting-data-in-pandas-bd09cb4c3d79) and [StackOverflow](https://stackoverflow.com/questions/22927181/selecting-specific-rows-and-columns-from-numpy-array) are your friends❗

# %% [markdown]
# # Import the data from Github
# You can use `pandas` to read .csv files from Github - check it out! Of course you could read the file locally and import it, but this is a nice hack.

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_train.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
# keep the first 10 rows per simplicity
df = df[0:10]
df # remeber that Python counts from 0!
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
# good luck! use nice headers for each question so that it is easy to grade. like below!

# %% [markdown]
# # Q1
# 1) Select the first 5 rows and all columns.

# %%
# make sure you have nice comments so it's easy to follow
# 0:5 means select rows including 0 up until but not including 5
# : means select all columns from start to end!
tmp = df.iloc[0:5, :]
print(tmp)
print('------------------')
print('The shape is:', tmp.shape)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
# ------------------
# The shape is: (5, 9)

# %% [markdown]
# # Q2
