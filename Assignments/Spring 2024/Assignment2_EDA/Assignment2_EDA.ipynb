# %% [markdown]
# # Individual Assignment 2: Basic EDA in Python
# **Dr. Dave Wanik - Dept. Operations and Information Management - University of Connecticut**
#
# -----------------------------------------------------------
#
# * Your Name: ___________
# * Your NetID: ____________
#
# Get your plots and tables on!!! We will use data related to the World Happiness Data to make some interesting plots and tables. We will use `matplotlib` (`pylab`), `seaborn`, `numpy` and `pandas` to do your analysis.
#
# * Quality of Life Data
#   * (raw data) https://www.numbeo.com/quality-of-life/rankings_by_country.jsp
#   * (clean .csv file ready to use! use gdown to get the data) https://drive.google.com/file/d/1xtYKN3FWErFgt3ZiYWJDONmSLfLpESVR/view?usp=sharing
#
# Note that there are only 83 rows in this 'numbeo' Quality of Life dataset, which means data for each country does not exist. We will learn about how to do interpolation to other regions later on. Here's a sneak peek if you want to see how to use a k-nearest neighbor imputation: https://scikit-learn.org/stable/modules/generated/sklearn.impute.KNNImputer.html
#
# **100 pts, 10 pts each.** I will deduct extra points if notebook is unorganized (aka no headers or comments). Feel free to ask your group for help, but do you own work - no direct copying or 0 on the assignment and final grade lowered.
#
# 1. Count the number of rows where `Quality of Life Index` is greater than 120. Make a new column called `Flag_QualityOfLife` where the value is `High` if greater than 120, otherwise `Low`.
# 2. [Read this documentation for seaborn](https://seaborn.pydata.org/generated/seaborn.pairplot.html) on how to make a 'pairplot' and a 'pairplot by group' using seaborn. Make a 'pairplot' for the entire dataset. Make a pairplot using the original dataset, then make the `pairplot by group` where the `hue=Flag_QualityOfLife`.
# 3. Write five bullet points in a text cell about some of the trends you see - for example, does the univariate distribution of some variables suprise you? What is the shape of the distributions? Is there a linear relationship between any of the variables? How do the explanatory variables relate to your target variable (`Quality of Life Index`)?
# 4. Calculate the 90th percentile of the `Quality of Life Index` column. Which countries have a `Quality of Life Index` greater than or equal to this value?
# 5. Make a histogram of `df['Pollution Index']` with nice titles, axes labels and colored blue. Add a bullet point describing what you see.
# 6. Make a histogram of `df['Health Care Index']` with nice titles, axes labels and colored red. Add a bullet point describing what you see.
# 7. Make a scatterplot using `x = Health Care Index` vs. `y = Quality of Life Index`,  with nice titles, axes labels, and a [cool marker symbol of your choice](https://matplotlib.org/stable/api/markers_api.html).
# 8. Make a kernel density plot of `Purchasing Power Index` [using seaborn](https://seaborn.pydata.org/generated/seaborn.kdeplot.html).
# 9. Now make a kernel density plot of `Purchasing Power Index` with `hue = Flag_QualityOfLife` [using seaborn](https://seaborn.pydata.org/generated/seaborn.kdeplot.html). Describe what you see.
# 10. [Read this blog post](https://medium.com/@szabo.bibor/how-to-create-a-seaborn-correlation-heatmap-in-python-834c0686b88e) and refer back to our class example. Now create a correlation matrix heatmap with NUMBERS ON IT (the pairwise correlations). Describe what you see.

# %%
# !pip install gdown==4.6.0

# %%
# https://drive.google.com/file/d/1xtYKN3FWErFgt3ZiYWJDONmSLfLpESVR/view?usp=sharing
# !gdown 1xtYKN3FWErFgt3ZiYWJDONmSLfLpESVR
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1xtYKN3FWErFgt3ZiYWJDONmSLfLpESVR
# To: /content/QOL.csv
# 100% 5.71k/5.71k [00:00<00:00, 13.6MB/s]

# %%
import pandas as pd
df = pd.read_csv('QOL.csv')

# %%
df
# Out:
#     Rank      Country  Quality of Life Index  Purchasing Power Index  \
# 0      1  Switzerland                 190.82                  110.96
# 1      2      Denmark                 190.01                   94.73
# 2      3  Netherlands                 183.31                   83.89
# 3      4      Finland                 182.79                   89.05
# 4      5      Austria                 182.37                   78.23
# ..   ...          ...                    ...                     ...
# 78    79  Philippines                  78.39                   19.71
# 79    80        Kenya                  75.77                   27.67
# 80    81   Bangladesh                  65.27                   24.07
# 81    82         Iran                  64.73                   19.00
# 82    83      Nigeria                  52.00                    9.78
#
#     Safety Index  Health Care Index  Cost of Living Index  \
# 0          78.65              74.47                131.75
# ...

# %% [markdown]
# # Question 1

# %%
# please add a nice header for each question like this so it's easy to grade
# add lots of comments everywhere and text cells so I can follow your
# logic and give partial credit!

# good luck!
