# %% [markdown]
# # Moving Average Homework
# --------------------------
# **Dr. Dave Wanik - University of Connecticut**

# %% [markdown]
# The purpose of this homework is to test your skills with moving average models. Let's explore this .csv file that has hourly observations of weather variables and energy consumption (Demand) and see which variable is easiest to predict.

# %%
# https://drive.google.com/file/d/1g3g17i4eRLnMs1ztkTaHcfdxcQzjwVGy/view?usp=sharing
# !gdown 1g3g17i4eRLnMs1ztkTaHcfdxcQzjwVGy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1g3g17i4eRLnMs1ztkTaHcfdxcQzjwVGy
# To: /content/BDL_cleanweather_energy.csv
# 100% 6.06M/6.06M [00:00<00:00, 62.4MB/s]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/BDL_cleanweather_energy.csv')

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# * Datetime: timestep of the operation - make sure you convert to datetime and set as index so you can use the power of moving average models!
# * Demand: Hourly energy usage (MWh)
# * tmpf:
# Air Temperature in Fahrenheit, typically @ 2 meters
# * dwpf: Dew Point Temperature in Fahrenheit, typically @ 2 meters
# * relh: Relative Humidity in %
# * drct: Wind Direction in degrees from *true* north
# * sknt: Wind Speed in knots
# * p01i: One hour precipitation for the period from the observation time to the time of the previous hourly precipitation reset. This varies slightly by site. Values are in inches. This value may or may not contain frozen precipitation melted by some device on the sensor or estimated by some other means. Unfortunately, we do not know of an authoritative database denoting which station has which sensor.
# * alti: Pressure altimeter in inches
# * mslp: Sea Level Pressure in millibar
# * vsby: Visibility in miles
#
# Source of weather data: https://mesonet.agron.iastate.edu/request/download.phtml

# %% [markdown]
# # Exploratory Data Analysis (30 points, 5 pts per plot/table)
# Make three nice plots and three nice tables showing the relationship between energy demand and weather. Univariate and bivariate plots must both be shown. Be creative with which tables you create - don't just make the same table over and over again.

# %% [markdown]
# # Moving Average Models! (60 points, 20 points per model)
# Pick three variables (like `Demand`, `tmpf` and `vsby`) to build a moving average model for. Make sure that you shift(1) so that you aren't having data leakage (like we talked about in class.) Keep the number of periods FIXED so that all variables are evaluated the same way.
#
# For each variable, fit the model (pick a constant window like 3 or 5 hours) and then evaluate the model with:
# 1. A scatterplot
# 2. Error metrics (R2, bias, MAE, MAPE)
# 3. A time series plot

# %% [markdown]
# # Discussion (10 points)
# Be quantitative and write 5 great bullet points about which model-variable combination did best - for example, what was easier to predict, Demand or temperature? Make some comments about other weather-based models that you might be able to create if you had the data.
