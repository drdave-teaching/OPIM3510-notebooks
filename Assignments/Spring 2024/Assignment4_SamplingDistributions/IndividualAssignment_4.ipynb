# %% [markdown]
# # Individual Assignment 4: Sampling Distributions and Confidence Intervals
# **Dr. Dave Wanik - University of Connecticut**
#
# ---------------------------------------------------------------------------
# * Your Name
# * Your NetID
#
# To be completed on your own individually - you may ask fellow students for help, but any directly copied answers from other students will results in a grade of 0 for the assignment, grade lowering or a failing grade for the class etc.
#
# Solve this BY HAND - on paper... take a picture, save as PDF, and upload the document to HuskyCT. Show all of your math. Make sure your name and netID are each page. Provide page numbers on each page (if needed.)
#
# ***Rubric:*** 100 pts total. 50 pts per question.

# %% [markdown]
# # Question 1
# The owner of Britten’s Egg Farm wants to estimate the mean number of eggs laid per chicken. A sample of 20 chickens shows they laid an average of 20 eggs per month with a standard deviation of 2 eggs per month.
#
# 1. What is the value of the population mean? What is the best estimate of this value? (Left intentionally blank)
# 2. Explain why we need to use the t distribution. What assumption do you need to make? (Left intentionally blank)
# 3. For a 95 percent confidence interval, what is the value of t? (2.093, write me the line of code you used to get this value of t! updated April 4, 2024.)
# 4. Develop the 95 percent confidence interval for the population man. (Between 19.06 and 20.94)
# 5. Would it be reasonable to conclude that the population mean is 21 eggs? What about 25 eggs? (Neither value is reasonable, students can explain why)

# %% [markdown]
# # Question 2
# The owner of the West End Kwick Fill Gas Station wishes to determine the proportion of customers who use a credit card or debit card to pay at the pump. He surveys 100 customers and finds that 80 paid at the pump.
# 1. Estimate the value of the population proportion. (0.8)
# 2. Develop a 95 percent confidence interval for the population proportion. (Between 0.72 and 0.88)
# 3. Interpret your findings. (Left intentionally blank).
