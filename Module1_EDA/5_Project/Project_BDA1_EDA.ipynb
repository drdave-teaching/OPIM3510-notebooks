# %% [markdown]
# # Project 1: EDA for BDA1 (Spring 2024)
# -----------------------
# **Dr. Dave Wanik - Dept. of Operations & Information Management - University of Connecticut**
#
# The purpose of this group project is to put your skills to the test!
#
# * Name
# * StudentID
# * NetID
#
# By submitting this work, I accept responsibility for our role in ensuring the integrity of the work submitted. I affirm that I have not given or received any unauthorized help on this assignment, and that this work is my own.

# %% [markdown]
# The rubric (point values) is given below in the subheaders. If code quality or notebook is sloppy, points will be deducted. If text narrative/captions are missing, points will be deducted. Your entire code should 'Run All' when executed (no bugs) - otherwise you may receive a 0 for the assignment. I want your best work!

# %%
# !pip install gdown==4.6.0
# Out:
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ...

# %% [markdown]
# # Background
#
# The Connecticut Data Collaborative ( [ctdata.org](ctdata.org)) has a treasure trove of city, county, zipcode and census-tract level data. Your goal in this project is to pick three different datasets  and join them together and tell a story about what you see in Connecticut.
#
# You have a lot of flexibility here in the datasets you choose - look here (https://www.ctdata.org/data-by-topic [link text](https://www.ctdata.org/data-by-topic)) for datasets that are easy to join together based on a primary key (common field.)
#
# * Business & Economy
# * Children & Families
# * Civic Engagement
# * Criminal Justice
# * Demographics & Population
# * Education
# * Hartford
# * Health & Healthcare
# * Housing
# * Migration
# * Regional/Town Data

# %% [markdown]
# # Part 1: Motivation (15 pts)
# What is the purpose of your analysis? Do you want to examine trends in different counties? Do you want to see if there is a relationship between education and demographics? Do you want to analyze where health outcomes are best in Connecticut? You have flexibility here. Provide at least ten sentences here and cite three sources in the narrative (provide citations as bullet points.)

# %% [markdown]
# # Part 2: Data Joining and Cleaning (25 pts)
#
# Here is an example of how to download a single table.
#
# * http://data.ctdata.org/visualization/households-with-children
#
# Click 'Raw Data' then 'Download' and a copy of the .csv or .xls file should download to your computer. Then drag onto your Google Drive. Then, make a shareable link 'Viewable to Anyone' and use gdown to download the data. This way all of your analysis lives in the Google Colab notebook - no data or permission issues! Here's an example of how to do this.

# %%
# !gdown 1ATwbwQz-i7HJVjQ9ZFouf06EQQpgUcu6
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ATwbwQz-i7HJVjQ9ZFouf06EQQpgUcu6
# To: /content/householdswithchildren-2019.csv
# 100% 73.2k/73.2k [00:00<00:00, 2.10MB/s]

# %%
# now read the file and rock!

# %% [markdown]
# I am interested in how clean and efficient your code is. Take good care to line your data up correctly. Duplicative columns should be deleted. Column names should make sense.

# %% [markdown]
# # Part 3: Three Amazing Tables (25 pts)
# Do not just do summary statistics or value counts - with your brand new, joined, clean dataset, I want you to conceptualize three interesting tables you can create. You may need to make more columns/features in your dataframe (I encourage you to experiment!) Your tables should be related to your motivation. Each table should have a caption with a description of what you see in the table.

# %% [markdown]
# ## Table 1: XYZ

# %% [markdown]
# ## Table 2: XYZ

# %% [markdown]
# ## Table 3: XYZ

# %% [markdown]
# # Part 4: Three Amazing Plots (25 pts)

# %% [markdown]
# Three amazing plots means you should have a nice mix of univariate and bivariate plots. If you want to read on your own and make a map (this is a great idea!), I encourage you to do so. You may want to come to office hours to ask if your plots are of sufficient quality!
#
# Each plot should be thoughtfully created with a caption describing what the figure shows, explaining how it relates to the motivation. The plot should have legible and sensible axes and titles and legend (if needed) with a pleasant selection of colors. Take your time and do a good job on these.

# %% [markdown]
# ## Plot 1: XYZ

# %% [markdown]
# ## Plot 2: XYZ

# %% [markdown]
# # Plot 3: XYZ

# %% [markdown]
# # Part 5: Conclusion (10 pts)
# Write five, detailed bullets about what you learned in this assignment, any big successes or challenges, any future research directions etc.
