# %% [markdown]
# # Project 3: Visualizing Uncertainty (Spatial Analytics)
# ----------------------------
# **Dr. Dave Wanik - University of Connecticut**

# %% [markdown]
# In a previous project, I had you all look at merging interesting datasets from CTData together. Many chose something related to demographics, income, education etc. Now I want you to revist that first project and identify if there was something missing... perhaps a closer look at UNCERTAINTY and resampling!

# %% [markdown]
# # Instructions
# 1. Choose the three datasets that you worked with from Project 1 (since you are already familiar with it) and join them to a town shapefile of Connecticut (we worked with these shapefiles in M3.2 and M3.3)
#   * Link to CTData: https://github.com/orgs/CT-Data-Collaborative/repositories
#   * Link to CT Town Polygon Shapefile: https://ct-deep-gis-open-data-website-ctdeep.hub.arcgis.com/datasets/CTDEEP::connecticut-towns-set/explore?layer=1&location=41.497268%2C-72.761769%2C8.45
#     * Make sure you download the shapefile (.shp) from this website if you use it!
#   * You can already guess that you will need to reshape your data and go from long to wide so that you end up with 169 (170) rows in your .csv file with a whole bunch of columns... be careful of how you name your columns, you will probably need to collapse the multi-index so that your column names look nice
#     * https://stackoverflow.com/questions/14507794/how-to-flatten-a-hierarchical-index-in-columns
#     * `df.columns = ["_".join(a) for a in df.columns.to_flat_index()]`
#     * `print(df.columns)`
# 2. Choose one variable from each of the three datasets that you want to tell a story about (for example, house prices, income and education attainment level)
# 3. Plot each variable for the oldest time step (for example, 2006)
#   * Plot the actual value
#   * Plot the low estimate (actual value - margin of error)
#   * Plot the upper estimate (actual value + margin of error)
#   * For each map you create, write a caption with two or three sentences that describes what you see.
# 4. Plot each variable for the newest time step (for example, 2020)
#   * Plot the actual value
#   * Plot the low estimate (actual value - margin of error)
#   * Plot the upper estimate (actual value + margin of error)
#   * For each map you create, write a caption with two or three sentences that describes what you see.
#
# *Note: you have to create a new feature in the geodataframe for the `low_estimate` and the `high_estimate`!*
#
# 5. Discussion: Comment on how things have changed from your old time step to the new time step: write at least 5 meaningful sentences (thoughtful, not short sentences) about how things have changed in Connecticut. Where is uncertainty the greatest vs. highest? You are welcome to make additional plots if you want to explore.
#
# 6. Resample one of the three variables from town data to county resolution and make a county map of the oldest and newest time step (just the actual estimate, not lower or upper estimate.)
#   * This will require you to take the average or sum of your variable of interest by county (can be done in pandas)... which you then need to join to a County-level shapefile (must be done with geopandas)
#   * Link to county shapefile: https://www2.census.gov/geo/tiger/TIGER2019/COUSUB/tl_2019_09_cousub.zip
#   * Plot should have a consistent legend between old and new timestep (So that you can really compare the colors and trends!)
#
# **Code clarity:**
# I want you to take pride in this assignment and to take your time on it. Use a subheader for each questions and plot. All plots should be BEAUTIFULLY labeled with legends, axis titles - use the same color ramp and legend values for each graph so that color formatting is consistent. I gave you a headstart with the headers below - please make this read like a professional report so it is easy to evaluate your work.
#   * To make the legends consistent, use `vmin` and `vmax` to set hard upper and lower bounds (could be 0 to 100 for a percentage) - this may take some 'tinkering' to decide on what the best values are. If you don't do this, the analysis won't make any sense (points off)
#     * https://stackoverflow.com/questions/73834049/change-colorbar-boundaries-in-geopandas-plot
#
# 7. Conclusion: write at least 5 great sentences about what you learned in this assignment, and about the variable you studied.
#
# 7. Extra credit: up to 10 points on final class grade (and for a letter of recommendation if you need it for a job/internship.) Fit an exponential smoothing model for each town (using the first N-1 years) and predict the last year ... how does your model do?! Evaluate your model with a map (actual and predicted) and scatterplot.

# %% [markdown]
# # 1. Data Cleaning (long to wide)
# Keep ALL columns... just explode them to wide format.

# %% [markdown]
# # 2. I am going to analyze Var1, Var2, Var3
# ...and join to town shapefile

# %% [markdown]
# # 3. Maps (town-resolution), oldest timestep

# %% [markdown]
# ## Var1

# %% [markdown]
# ### Actual estimate

# %% [markdown]
# ### Low estimate

# %% [markdown]
# ### High estimate

# %% [markdown]
# ## Var2

# %% [markdown]
# ### Actual estimate

# %% [markdown]
# ### Low estimate

# %% [markdown]
# ### High estimate

# %% [markdown]
# ## Var3

# %% [markdown]
# ### Actual estimate

# %% [markdown]
# ### Low estimate

# %% [markdown]
# ### High estimate

# %% [markdown]
# # 4. Maps (town-resolution), newest timestep

# %% [markdown]
# ## Var1

# %% [markdown]
# ### Actual estimate

# %% [markdown]
# ### Low estimate

# %% [markdown]
# ### High estimate

# %% [markdown]
# ## Var2

# %% [markdown]
# ### Actual estimate

# %% [markdown]
# ### Low estimate

# %% [markdown]
# ### High estimate

# %% [markdown]
# ## Var3

# %% [markdown]
# ### Actual estimate

# %% [markdown]
# ### Low estimate

# %% [markdown]
# ### High estimate

# %% [markdown]
# # 5. Discussion
# What has changed in your three variables over time? Where is uncertainty the greatest? Do you have missing data?

# %% [markdown]
# # 6. Resampling one variable to county resolution
# The variable I am going to analyze at county-resolution is...

# %% [markdown]
# ## Data prep and joining

# %% [markdown]
# ## Map of oldest timestep

# %% [markdown]
# ## Map of newest timestep

# %% [markdown]
# # Conclusion

# %% [markdown]
# # (optional) Extra credit
